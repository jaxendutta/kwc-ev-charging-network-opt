# %% [markdown]
# # EV Charging Station Optimization - Data Exploration
#
# This notebook explores the current EV charging infrastructure in the Kitchener-Waterloo region using real data from OpenChargeMap.

# %%
import sys
from pathlib import Path

# Add src directory to Python path
src_dir = Path.cwd().parent / 'src'
sys.path.append(str(src_dir))

# Imports
import pandas as pd
from data.api_client import OpenChargeMapClient

# Initialize API client
client = OpenChargeMapClient()

# Fetch fresh data
stations_df = client.fetch_stations(force_refresh=True)

print("\nData Summary:")
print(f"Total stations found: {len(stations_df)}")
print("\nCharger Types:")
print(stations_df['charger_type'].value_counts())
print("\nOperators:")
print(stations_df['operator'].value_counts())
# Out:
# API key loaded (starts with: cf3da...)
# Fetching charging station data from OpenChargeMap API...
# Found 10 charging stations
# Cached 7 stations in KW region
#
# Data Summary:
# Total stations found: 7
#
# Charger Types:
# charger_type
# Level 2    4
# Level 3    3
# Name: count, dtype: int64
#
# Operators:
# operator
# flo                    4
# Sun Country Highway    2
# Jule                   1
# Name: count, dtype: int64

# %% [markdown]
# ## Current Charging Station Distribution

# %%
import visualization.map_viz as map_viz

# Create and display map
m = map_viz.create_kw_map()
m = map_viz.plot_charging_stations(m, stations_df)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd611213c6cf543d95fbccc42ee73eb0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position: fixed;
#                 bottom: 50px;
#                 left: 50px;
#                 z-index: 1000;
#                 background-color: white;
#                 padding: 10px;
#                 border: 2px solid grey;
#                 border-radius: 5px;&quot;&gt;
#         &lt;h4 style=&quot;margin: 0 0 10px 0;&quot;&gt;Charging Stations&lt;/h4&gt;
#         &lt;p style=&quot;margin: 2px 0;&quot;&gt;&lt;span style=&#x27;color: blue;&#x27;&gt;●&lt;/span&gt; Level 1: 0&lt;/p&gt;
#         &lt;p style=&quot;margin: 2px 0;&quot;&gt;&lt;span style=&#x27;color: green;&#x27;&gt;●&lt;/span&gt; Level 2: 4&lt;/p&gt;
#         &lt;p style=&quot;margin: 2px 0;&quot;&gt;&lt;span style=&#x27;color: red;&#x27;&gt;●&lt;/span&gt; Level 3: 3&lt;/p&gt;
#         &lt;p style=&quot;margin: 2px 0;&quot;&gt;&lt;span style=&#x27;color: gray;&#x27;&gt;●&lt;/span&gt; Unknown: 0&lt;/p&gt;
#         &lt;hr style=&quot;margin: 5px 0;&quot;&gt;
#         &lt;p style=&quot;margin: 2px 0;&quot;&gt;&lt;b&gt;Total Stations:&lt;/b&gt; 7&lt;/p&gt;
#         &lt;p style=&quot;margin: 2px 0;&quot;&gt;&lt;b&gt;Total Chargers:&lt;/b&gt; 12&lt;/p&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd611213c6cf543d95fbccc42ee73eb0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cd611213c6cf543d95fbccc42ee73eb0 = L.map(
#                 &quot;map_cd611213c6cf543d95fbccc42ee73eb0&quot;,
#                 {
#                     center: [43.4516, -80.4925],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa41d2b24b8643ba0ca080bb0c1f9620 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fa41d2b24b8643ba0ca080bb0c1f9620.addTo(map_cd611213c6cf543d95fbccc42ee73eb0);
#
#
#             var circle_marker_e5853ff02fab4a7602ef6172d89ee66d = L.circleMarker(
#                 [43.459231, -80.536434],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cd611213c6cf543d95fbccc42ee73eb0);
#
#
#         var popup_b5f6fb7c3e8ab22e1c5abd509013207e = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_a3ee282ecf21b2e3e7a3eabffdd5cdf7 = $(`&lt;div id=&quot;html_a3ee282ecf21b2e3e7a3eabffdd5cdf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;div style=&quot;font-family: Arial; max-width: 300px;&quot;&gt;             &lt;h4 style=&quot;margin-bottom: 5px;&quot;&gt;Urban Lofts&lt;/h4&gt;             &lt;p style=&quot;margin: 2px 0;&quot;&gt;&lt;b&gt;Type:&lt;/b&gt; Level 2&lt;/p&gt;             &lt;p style=&quot;margin: 2px 0;&quot;&gt;&lt;b&gt;Chargers:&lt;/b&gt; 1&lt;/p&gt;             &lt;p style=&quot;margin: 2px 0;&quot;&gt;&lt;b&gt;Operator:&lt;/b&gt; flo&lt;/p&gt;             &lt;p style=&quot;margin: 2px 0;&quot;&gt;&lt;b&gt;Cost:&lt;/b&gt; £1.50/hour&lt;/p&gt;             &lt;hr style=&quot;margin: 5px 0;&quot;&gt;             &lt;p style=&quot;margin: 2px 0;&quot;&gt;&lt;small&gt;98 Farley Drive&lt;br&gt;             Guelph, None&lt;/small&gt;&lt;/p&gt;         &lt;/div&gt;         &lt;/div&gt;`)[0];
#                 popup_b5f6fb7c3e8ab22e1c5abd509013207e.setContent(html_a3ee282ecf21b2e3e7a3eabffdd5cdf7);
#
#
#
#         circle_marker_e5853ff02fab4a7602ef6172d89ee66d.bindPopup(popup_b5f6fb7c3e8ab22e1c5abd509013207e)
#         ;
#
#
#
#
#             var circle_marker_a1a64d7ee1625967bb408751d1d8d3e2 = L.circleMarker(
#                 [43.485057, -80.523934],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cd611213c6cf543d95fbccc42ee73eb0);
#
#
#         var popup_fea03891f4a75f683f96217b2524a4df = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_6abfd9f39d9dd1339d9fa03697a4e4bd = $(`&lt;div id=&

# %% [markdown]
# ## Infrastructure Analysis

# %%
print("Charger Types by Operator:")
print(pd.crosstab(stations_df['operator'], stations_df['charger_type']))

print("\nAverage Chargers per Station by Type:")
print(stations_df.groupby('charger_type')['num_chargers'].mean())

print("\nCharging Station Density:")
area_km2 = 200  # Approximate KW region area
print(f"Stations per km²: {len(stations_df)/area_km2:.2f}")
print(f"Chargers per km²: {stations_df['num_chargers'].sum()/area_km2:.2f}")
# Out:
# Charger Types by Operator:
# charger_type         Level 2  Level 3
# operator
# Jule                       0        1
# Sun Country Highway        2        0
# flo                        2        2
#
# Average Chargers per Station by Type:
# charger_type
# Level 2    1.250000
# Level 3    2.333333
# Name: num_chargers, dtype: float64
#
# Charging Station Density:
# Stations per km²: 0.04
# Chargers per km²: 0.06
